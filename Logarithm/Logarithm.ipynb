# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('revenue.csv')
df
# Out:
#          company  revenue
# 0         Tesla      31.0
# 1           UBER     11.0
# 2         Amazon    386.0
# 3  Jindal  Steel      4.7
# 4      Axis Bank      5.6
# 5        Vedanta     11.3

# %%
sns.barplot(x='company',y='revenue',data=df)
# Out:
# <Axes: xlabel='company', ylabel='revenue'>

# %%
sns.barplot(x=df['company'],y=df['revenue'],data=df)
plt.yscale('log')
